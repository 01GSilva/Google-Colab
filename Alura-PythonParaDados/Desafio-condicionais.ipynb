# %% [markdown]
# Vamos praticar o uso de estruturas condicionais como o if, else e elif a partir de algumas atividades. Agora que estamos avançando nos conteúdos, podemos tornar os desafios mais interessantes: vamos trabalhar com projetos de código! Solucione os problemas de aquecimento para se preparar para os projetos:

# %% [markdown]
# ## Aquecendo na programação

# %% [markdown]
# 1) Escreva um programa que peça à pessoa usuária para fornecer dois números e exibir o número maior.

# %%
n1 = float(input('Digite o primeiro numeros: '))
n2 = float(input('Digite o segundo numeros: '))

if n1 > n2:
    print(f'{n1} é o maior valor')
else:
    print(f'{n2} é o maior valor')
# Out:
# 99.0 é o maior valor

# %% [markdown]
# 2) Escreva um programa que solicite o percentual de crescimento de produção de uma empresa e informe se houve um crescimento (porcentagem positiva) ou decrescimento (porcentagem negativa).

# %%
percent = float(input('Digite o percentual de crescimento: '))

if percent > 0:
    print('A empresa cresceu.')
elif percent == 0:
    print('Não houve crescimento.')
else:
    print('A empresa diminuiu')
# Out:
# A empresa diminuiu

# %% [markdown]
# 3) Escreva um programa que determine se uma letra fornecida pela pessoa usuária é uma vogal ou consoante.

# %%
letra = input('Digite alguma letra: ')
vogais = ['a','e','i','o','u']

if letra in vogais:
    print(f'A letra {letra} é uma vogal')
else:
    print(f'A letra {letra} é uma consoante')
# Out:
# A letra f é uma consoante

# %% [markdown]
# 4) Escreva um programa que leia valores médios de preços de um modelo de carro por 3 anos consecutivos e exiba o valor mais alto e mais baixo entre esses três anos.

# %%
v1 = float(input('Digite o valor do carro no primeiro ano: '))
v2 = float(input('Digite o valor do carro no segundo ano: '))
v3 = float(input('Digite o valor do carro no terceiro ano: '))

if v1 > v2 and v1 > v3:
    print(f'O valor mais alto foi {v1}')
elif v2 > v1 and v2 > v3:
    print(f'O valor mais alto foi {v2}')
else:
    print(f'O valor mais alto foi {v3}')

if v1 < v2 and v1 < v3:
    print(f'O valor mais baixo foi {v1}')
elif v2 < v1 and v2 < v3:
    print(f'O valor mais baixo foi {v2}')
else:
    print(f'O valor mais baixo foi {v3}')
# Out:
# O valor mais alto foi 1000.0
# O valor mais baixo foi 0.4

# %% [markdown]
# 5) Escreva um programa que pergunte sobre o preço de três produtos e indique qual é o produto mais barato para comprar.

# %%
p1 = float(input('Digite o valor do produto 1: '))
p2 = float(input('Digite o valor do produto 2: '))
p3 = float(input('Digite o valor do produto 3: '))

if p1 < p2 and p1 < p3:
    print(f'o produto mais barato é o produto 1 (R$ {p1})')
elif p2 < p1 and p2 < p3:
    print(f'o produto mais barato é o produto 2 (R$ {p2})')
else:
    print(f'o produto mais barato é o produto 3 (R$ {p3})')
# Out:
# o produto mais barato é o produto 2 (R$ 3.0)

# %% [markdown]
# 6) Escreva um programa que leia três números e os exiba em ordem decrescente.

# %%
v1 = float(input('Primeiro valor: '))
v2 = float(input('Segundo valor: '))
v3 = float(input('Terceiro valor: '))

maior = 0
medio = 0
menor = 0

if v1 > v2 and v1 > v3:
    maior = v1
    if v2 > v3:
        medio = v2
        menor = v3
    else:
        medio = v3
        menor = v2

elif v2 > v1 and v2 > v3:
    maior = v2
    if v1 > v3:
        medio = v1
        menor = v3
    else:
        medio = v3
        menor = v1

else:
    maior = v3
    if v1 > v2:
        medio = v1
        menor = v2
    else:
        medio = v2
        menor = v1


print(f'{maior}, {medio}, {menor}')
# Out:
# 2000.0, 30.0, 5.0

# %% [markdown]
# 7) Escreva um programa que pergunte em qual turno a pessoa usuária estuda ("manhã", "tarde" ou "noite") e exiba a mensagem "Bom Dia!", "Boa Tarde!", "Boa Noite!", ou "Valor Inválido!", conforme o caso.

# %%
turno = input('Qual turno você estuda (manhã, tarde ou noite) ?: ')

if turno == 'manhã':
    print('Bom dia')
elif turno == 'tarde':
    print('Boa tarde')
elif turno == 'noite':
    print('Boa Noite')
else:
    print('Valor inválido')
# Out:
# Valor inválido

# %% [markdown]
# 8) Escreva um programa que peça um número inteiro à pessoa usuária e determine se ele é par ou ímpar. Dica: Você pode utilizar o operador módulo %.

# %%
valor = int(input('Digite um numero inteiro: '))

if valor % 2 == 0:
    print(f'{valor} é um número par')
else:
    print(f'{valor} é um número impar')
# Out:
# 51 é um número impar

# %% [markdown]
# 9) Escreva um programa que peça um número à pessoa usuária e informe se ele é inteiro ou decimal.

# %%
valor = float(input('Digite um valor: '))

if (valor // 1) == valor:
    print(f'O número {valor} é um número inteiro')
else:
    print(f'O número {valor} é um número decimal')
# Out:
# O número 1.2 é um número decimal

# %% [markdown]
# ## Momento dos projetos

# %% [markdown]
# 10) Um programa deve ser escrito para ler dois números e, em seguida, perguntar à pessoa usuária qual operação ele deseja realizar. O resultado da operação deve incluir informações sobre o número - se é par ou ímpar, positivo ou negativo e inteiro ou decimal.

# %%
n1 = float(input('Digite o primeiro valor: '))
operacao = input('Qual operação deseja fazer ( + , - , / , *) ?: ')
n2 = float(input('Digite o segundo valor: '))

if operacao == '+':
    res = n1 + n2
    print(f'A soma de {n1} + {n2} é {res}')

elif operacao == '-':
    res = n1 - n2
    print(f'A subtração de {n1} - {n2} é {res}')

elif operacao == '/':
    res = n1 / n2
    print(f'A divisão de {n1} / {n2} é {res}')

elif operacao == '*':
    res = n1 * n2
    print(f'A multiplicação de {n1} * {n2} é {res}')

else:
    print('OPERCAÇÃO INVALIDA')


if res % 2 == 0:
    par_impar = 'par'
else:
    par_impar = 'impar'

if res > 0:
    sinal = 'positivo'
else:
    sinal = 'negativo'

if res - (res // 1) == 0:
    int_dec = 'inteiro'
else:
    int_dec = 'decimal'

print(f'{res} é {par_impar}, {sinal} e {int_dec}')
# Out:
# A divisão de 9.0 / -4.0 é -2.25
# -2.25 é impar, negativo e decimal

# %% [markdown]
# 11) Escreva um programa que peça à pessoa usuária três números que representam os lados de um triângulo. O programa deve informar se os valores podem ser utilizados para formar um triângulo e, caso afirmativo, se ele é equilátero, isósceles ou escaleno. Tenha em mente algumas dicas:
#
#     1. Três lados formam um triângulo quando a soma de quaisquer dois lados for maior que o terceiro;
#     2. Triângulo Equilátero: três lados iguais;
#     3. Triângulo Isósceles: quaisquer dois lados iguais;
#     4. Triângulo Escaleno: três lados diferentes.

# %%
lado_a = float(input('Digite o comprimento do primeiro lado: '))
lado_b = float(input('Digite o comprimento do segundo lado: '))
lado_c = float(input('Digite o comprimento do terceiro lado: '))

if (lado_a + lado_b) < lado_c or (lado_a + lado_c) < lado_b or (lado_b + lado_c) < lado_a:
    print(f'Os comprimentos {lado_a}, {lado_b} e {lado_c} são insuficientes para criar um triangulo.')

elif lado_a == lado_b == lado_c:
    print(f'{lado_a}, {lado_b} e {lado_c} formam um triangulo equilatero.')

elif lado_a == lado_b or lado_a == lado_c or lado_b == lado_c:
    print(f'{lado_a}, {lado_b} e {lado_c} formam um triangulo Isóceles.')

else:
    print(f'{lado_a}, {lado_b} e {lado_c} formam um triangulo Escaleno.')
# Out:
# 5.0, 5.0 e 5.0 formam um triangulo equilatero.

# %% [markdown]
# 12) Um estabelecimento está vendendo combustíveis com descontos variados. Para o etanol, se a quantidade comprada for até 15 litros, o desconto será de 2% por litro. Caso contrário, será de 4% por litro. Para o diesel, se a quantidade comprada for até 15 litros, o desconto será de 3% por litro. Caso contrário, será de 5% por litro. O preço do litro de diesel é R$ 2,00 e o preço do litro de etanol é R$ 1,70. Escreva um programa que leia a quantidade de litros vendidos e o tipo de combustível (E para etanol e D para diesel) e calcule o valor a ser pago pelo cliente. Tenha em mente algumas dicas:
#
#     1. O do valor do desconto será a multiplicação entre preço do litro, quantidade de litros e o valor do desconto.
#     2. O valor a ser pago por um cliente será o resultado da multiplicação do preço do litro pela quantidade de litros menos o valor de desconto resultante do cálculo.

# %%
tipo =  input('Informe o combustivel da venda (E para Etanol e D para Diesel): ')
quantidade = float(input('Informe a quantidade de litros vendidos: '))

if tipo == 'E' or tipo == 'e':
    combustivel = 'Etanol'
    if quantidade <= 15:
        desconto = 2/100
        perc = '2%'
    else:
        desconto = 4/100
        perc = '4%'
    valor_desconto = (1.70 * quantidade) * desconto
    valor_final = (1.70 * quantidade) - valor_desconto
    print(f'O valor final do {combustivel} com desconto de {perc} é de: R$ {valor_final}')

elif tipo == 'D' or tipo == 'd':
    combustivel = 'Diesel'
    if quantidade <= 15:
        desconto = 3/100
        perc = '3%'
    else:
        desconto = 5/100
        perc = '5%'
    valor_desconto = (2.00 * quantidade) * desconto
    valor_final = (2.00 * quantidade) - valor_desconto
    print(f'O valor final do {combustivel} com desconto de {perc} é de: R$ {valor_final}')
# Out:
# O valor final do Diesel com desconto de 5% é de: R$ 190.0

# %% [markdown]
# 13) Em uma empresa de venda de imóveis você precisa criar um código que analise os dados de vendas anuais para ajudar a diretoria na tomada de decisão. O código precisa coletar os dados de quantidade de venda durante os anos de 2022 e 2023 e fazer um cálculo de variação percentual. A partir do valor da variação, deve ser enviada às seguintes sugestões:
#
# 1. Para variação acima de 20%: bonificação para o time de vendas.
# 2. Para variação entre 2% e 20%: pequena bonificação para time de vendas.
# 3. Para variação entre 2% e -10%: planejamento de políticas de incentivo às vendas.
# 4. Para variação abaixo de -10%: corte de gastos.

# %%
vendas_2022 = float(input('Digite o valor de vendas do ano de 2022: '))
vendas_2023 = float(input('Digite o valor de vendas do ano de 2023: '))

variacao = vendas_2023 - vendas_2022
perc = (variacao*100) / vendas_2022

if perc >= 20:
    print(f'Variacao de {perc}%. Bonificação para o time de vendas.')
elif 2 <= perc < 20:
    print(f'Variacao de {perc}%. Pequena bonificação para o time de vendas.')
elif -10 <= perc < 2:
    print(f'Variacao de {perc}%. Planejamento de politicas e incentivo a vendas.')
else:
    print(f'Variacao de {perc}%. Corte de gastos.')
# Out:
# Variacao de 12.3485%. Pequena bonificação para o time de vendas.
