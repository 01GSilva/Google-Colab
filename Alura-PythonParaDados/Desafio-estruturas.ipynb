# %% [markdown]
# # Aquecendo na programação

# %% [markdown]
# 1) Faça um programa que tenha a seguinte lista contendo os valores de gastos de uma empresa de papel [2172.54, 3701.35, 3518.09, 3456.61, 3249.38, 2840.82, 3891.45, 3075.26, 2317.64, 3219.08]. Com esses valores, faça um programa que calcule a média de gastos. Dica: use as funções built-in sum() e len().

# %%
gastos = [2172.54, 3701.35, 3518.09, 3456.61, 3249.38, 2840.82, 3891.45, 3075.26, 2317.64, 3219.08]
media = sum(gastos) / len(gastos)
media
# Out:
# 3144.222

# %% [markdown]
# 2) Com os mesmos dados da questão anterior, defina quantas compras foram realizadas acima de 3000 reais e calcule a porcentagem quanto ao total de compras.

# %%
contador = 0
soma = 0
for compra in gastos:
    if compra >= 3000:
        soma = soma + compra
        contador += 1

print(f'Foram feitas {contador} compras acima de R$ 3000,00, totalizando R${soma} gastos')

percentagem = (soma * 100) / sum(gastos)

print(f'Isso corresponde a {percentagem}% do valor total.')
# Out:
# Foram feitas 7 compras acima de R$ 3000,00, totalizando R$24111.22 gastos
# Isso corresponde a 76.68421631805896% do valor total.

# %% [markdown]
# 3) Faça um código que colete em uma lista 5 números inteiros quaisquer e imprima a lista. Exemplo: [1,4,7,2,4].

# %%
lista=[]
for i in range(1,6):
    n = int(input(f'Digite o {i}º numero inteiro: '))
    lista.append(n)
print(lista)
# Out:
# [1, 4, 7, 2, 4]

# %% [markdown]
# 4) Colete novamente 5 inteiros e imprima a lista em ordem inversa à enviada.

# %%
lista=[]
for i in range(1,6):
    n = int(input(f'Digite o {i}º numero inteiro: '))
    lista.append(n)
print(lista)

lista_inversa = []
index = 4
while index >= 0:
    lista_inversa.append(lista[index])
    index -= 1

print(lista_inversa)
# Out:
# [1, 4, 7, 2, 4]
# [4, 2, 7, 4, 1]

# %% [markdown]
# 5) Faça um programa que, ao inserir um número qualquer, cria uma lista contendo todos os números primos entre 1 e o número digitado.

# %%
limite = int(input('Digite um numero inteiro: '))
primos = []

for num in range(2, limite + 1):
    primo = True
    for i in range(2, num):
        if num % i == 0:
            primo = False
            break
    if primo == True:
        primos.append(num)

print(primos)
# Out:
# [2, 3, 5, 7, 11]

# %% [markdown]
# 6) Escreva um programa que peça uma data informando o dia, mês e ano e determine se ela é válida para uma análise.

# %%
while True:
    entrada = (input('Digite uma data (DD/MM/AAAA) ou 0 para sair: '))

    if entrada == '0':
        break
    
    else:
        data_sep = entrada.replace('/',' ')
        lista_str = data_sep.split()
        lista_int = []

        for i in lista_str:
            lista_int.append(int(i))

        if (lista_int[0] <= 0) or (lista_int[0] > 31):
            print('Dia inválido! Digite a data novamente. ')

        elif (lista_int[1] <=0) or (lista_int[1] > 12):
            print('Mês inválido! Digite a data novamente. ')

        elif lista_int[2] <= 0:
            print('Ano inválido! Digite a data novamente. ')

        else:
            print(f'Data {entrada} confirmada')

# %% [markdown]
# # Momento dos projetos

# %% [markdown]
# 7) Para um estudo envolvendo o nível de multiplicação de bactérias em uma colônia, foi coletado o número de bactérias por dia (em milhares) e pode ser observado a seguir: [1.2, 2.1, 3.3, 5.0, 7.8, 11.3, 16.6, 25.1, 37.8, 56.9]. Tendo esses valores, faça um código que gere uma lista contendo o percentual de crescimento de bactérias por dia, comparando o número de bactérias em cada dia com o número de bactérias do dia anterior. Dica: para calcular o percentual de crescimento usamos a seguinte equação: 100 * (amostra_atual - amostra_passada) / (amostra_passada).

# %%
entrada = [1.2, 2.1, 3.3, 5.0, 7.8, 11.3, 16.6, 25.1, 37.8, 56.9]

for i in range(1,len(entrada)):
    crescimento = (100*(entrada[i] - entrada[i-1]))/(entrada[i-1])
    print(f'Taxa de crescimento no {i} dia: {crescimento}%')
# Out:
# Taxa de crescimento no 1 dia: 75.00000000000001%
# Taxa de crescimento no 2 dia: 57.142857142857125%
# Taxa de crescimento no 3 dia: 51.51515151515153%
# Taxa de crescimento no 4 dia: 56.0%
# Taxa de crescimento no 5 dia: 44.87179487179489%
# Taxa de crescimento no 6 dia: 46.90265486725664%
# Taxa de crescimento no 7 dia: 51.20481927710843%
# Taxa de crescimento no 8 dia: 50.59760956175297%
# Taxa de crescimento no 9 dia: 50.52910052910054%

# %% [markdown]
# 8) Para uma seleção de produtos alimentícios, precisamos separar o conjunto de IDs dados por números inteiros sabendo que os produtos com ID par são doces e os com ID ímpar são amargos. Monte um código que colete 10 IDs. Depois, calcule e mostre a quantidade de produtos doces e amargos.

# %%
produtos = []
doces = 0
amargos = 0

for i in range(1,11):
    produto = int(input(f'Digite o ID do {i} produto: '))
    produtos.append(produto)

for id in produtos:
    if id%2 == 0:
        doces += 1
    
    else:
        amargos += 1

print(f'São {doces} produtos doces e {amargos} produtos amargos')
# Out:
# São 10 produtos doces e 0 produtos amargos

# %% [markdown]
# 9) Desenvolva um programa que informa a nota de um(a) aluno(a) de acordo com suas respostas. Ele deve pedir a resposta desse(a) aluno(a) para cada questão e é preciso verificar se a resposta foi igual ao gabarito. Cada questão vale um ponto e existem as alternativas A, B, C ou D.
