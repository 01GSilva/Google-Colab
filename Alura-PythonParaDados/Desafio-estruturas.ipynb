# %% [markdown]
# # Aquecendo na programação

# %% [markdown]
# 1) Faça um programa que tenha a seguinte lista contendo os valores de gastos de uma empresa de papel [2172.54, 3701.35, 3518.09, 3456.61, 3249.38, 2840.82, 3891.45, 3075.26, 2317.64, 3219.08]. Com esses valores, faça um programa que calcule a média de gastos. Dica: use as funções built-in sum() e len().

# %%
gastos = [2172.54, 3701.35, 3518.09, 3456.61, 3249.38, 2840.82, 3891.45, 3075.26, 2317.64, 3219.08]
media = sum(gastos) / len(gastos)
media
# Out:
# 3144.222

# %% [markdown]
# 2) Com os mesmos dados da questão anterior, defina quantas compras foram realizadas acima de 3000 reais e calcule a porcentagem quanto ao total de compras.

# %%
contador = 0
soma = 0
for compra in gastos:
    if compra >= 3000:
        soma = soma + compra
        contador += 1

print(f'Foram feitas {contador} compras acima de R$ 3000,00, totalizando R${soma} gastos')

percentagem = (soma * 100) / sum(gastos)

print(f'Isso corresponde a {percentagem}% do valor total.')
# Out:
# Foram feitas 7 compras acima de R$ 3000,00, totalizando R$24111.22 gastos
# Isso corresponde a 76.68421631805896% do valor total.

# %% [markdown]
# 3) Faça um código que colete em uma lista 5 números inteiros quaisquer e imprima a lista. Exemplo: [1,4,7,2,4].

# %%
lista=[]
for i in range(1,6):
    n = int(input(f'Digite o {i}º numero inteiro: '))
    lista.append(n)
print(lista)
# Out:
# [1, 4, 7, 2, 4]

# %% [markdown]
# 4) Colete novamente 5 inteiros e imprima a lista em ordem inversa à enviada.

# %%
lista=[]
for i in range(1,6):
    n = int(input(f'Digite o {i}º numero inteiro: '))
    lista.append(n)
print(lista)

lista_inversa = []
index = 4
while index >= 0:
    lista_inversa.append(lista[index])
    index -= 1

print(lista_inversa)
# Out:
# [1, 4, 7, 2, 4]
# [4, 2, 7, 4, 1]

# %% [markdown]
# 5) Faça um programa que, ao inserir um número qualquer, cria uma lista contendo todos os números primos entre 1 e o número digitado.

# %%
limite = int(input('Digite um numero inteiro: '))
primos = []

for num in range(2, limite + 1):
    primo = True
    for i in range(2, num):
        if num % i == 0:
            primo = False
            break
    if primo == True:
        primos.append(num)

print(primos)
# Out:
# [2, 3, 5, 7, 11]

# %% [markdown]
# 6) Escreva um programa que peça uma data informando o dia, mês e ano e determine se ela é válida para uma análise.

# %%
while True:
    entrada = (input('Digite uma data (DD/MM/AAAA) ou 0 para sair: '))

    if entrada == '0':
        break
    
    else:
        data_sep = entrada.replace('/',' ')
        lista_str = data_sep.split()
        lista_int = []

        for i in lista_str:
            lista_int.append(int(i))

        if (lista_int[0] <= 0) or (lista_int[0] > 31):
            print('Dia inválido! Digite a data novamente. ')

        elif (lista_int[1] <=0) or (lista_int[1] > 12):
            print('Mês inválido! Digite a data novamente. ')

        elif lista_int[2] <= 0:
            print('Ano inválido! Digite a data novamente. ')

        else:
            print(f'Data {entrada} confirmada')

# %% [markdown]
# # Momento dos projetos

# %% [markdown]
# 7) Para um estudo envolvendo o nível de multiplicação de bactérias em uma colônia, foi coletado o número de bactérias por dia (em milhares) e pode ser observado a seguir: [1.2, 2.1, 3.3, 5.0, 7.8, 11.3, 16.6, 25.1, 37.8, 56.9]. Tendo esses valores, faça um código que gere uma lista contendo o percentual de crescimento de bactérias por dia, comparando o número de bactérias em cada dia com o número de bactérias do dia anterior. Dica: para calcular o percentual de crescimento usamos a seguinte equação: 100 * (amostra_atual - amostra_passada) / (amostra_passada).

# %%
entrada = [1.2, 2.1, 3.3, 5.0, 7.8, 11.3, 16.6, 25.1, 37.8, 56.9]

for i in range(1,len(entrada)):
    crescimento = (100*(entrada[i] - entrada[i-1]))/(entrada[i-1])
    print(f'Taxa de crescimento no {i} dia: {crescimento}%')
# Out:
# Taxa de crescimento no 1 dia: 75.00000000000001%
# Taxa de crescimento no 2 dia: 57.142857142857125%
# Taxa de crescimento no 3 dia: 51.51515151515153%
# Taxa de crescimento no 4 dia: 56.0%
# Taxa de crescimento no 5 dia: 44.87179487179489%
# Taxa de crescimento no 6 dia: 46.90265486725664%
# Taxa de crescimento no 7 dia: 51.20481927710843%
# Taxa de crescimento no 8 dia: 50.59760956175297%
# Taxa de crescimento no 9 dia: 50.52910052910054%

# %% [markdown]
# 8) Para uma seleção de produtos alimentícios, precisamos separar o conjunto de IDs dados por números inteiros sabendo que os produtos com ID par são doces e os com ID ímpar são amargos. Monte um código que colete 10 IDs. Depois, calcule e mostre a quantidade de produtos doces e amargos.

# %%
produtos = []
doces = 0
amargos = 0

for i in range(1,11):
    produto = int(input(f'Digite o ID do {i} produto: '))
    produtos.append(produto)

for id in produtos:
    if id%2 == 0:
        doces += 1
    
    else:
        amargos += 1

print(f'São {doces} produtos doces e {amargos} produtos amargos')
# Out:
# São 5 produtos doces e 5 produtos amargos

# %% [markdown]
# 9) Desenvolva um programa que informa a nota de um(a) aluno(a) de acordo com suas respostas. Ele deve pedir a resposta desse(a) aluno(a) para cada questão e é preciso verificar se a resposta foi igual ao gabarito. Cada questão vale um ponto e existem as alternativas A, B, C ou D.

# %%
gabarito = ['D','A','C','B','A','D','C','C','A','B']
respostas = []
nota = 0

for i in range(1,11):
    resposta = input(f'Digite a resposta da {i}ª questão: ')
    respostas.append(resposta)

for i in range(0,10):
    if respostas[i] == gabarito[i]:
        nota += 1

print(f'Nota da prova: {nota}')
# Out:
# Nota da prova: 7

# %% [markdown]
# 10) Um instituto de meteorologia deseja fazer um estudo de temperatura média de cada mês do ano. Para isso, você precisa fazer um código que colete e armazene essas temperaturas médias em uma lista. Depois, calcule a média anual das temperaturas e mostre todas as temperaturas acima da média anual e em que mês elas ocorreram, mostrando os meses por extenso (Janeiro, Fevereiro, etc.).

# %%
meses = ['Janeiro','Fevereiro','Março','Abril','Maio','Junho','Julho','Agosto','Setembro','Outubro','Novembro','Dezembro']
temperaturas = []

for i in range(0,12):
    temperatura = float(input(f'Digite a temperatura no mes de {meses[i]}: '))
    temperaturas.append(temperatura)

temperatura_media = sum(temperaturas)/12

index = []

for i in range(0,12):
    if temperaturas[i] > temperatura_media:
        index.append(i)

print(f'A média anual de temperaturas foi de {temperatura_media} graus Celsius. Os meses acima da média foram: ')
for i in index:
    print(f'{meses[i]}: {temperaturas[i]}')
# Out:
# A média anual de temperaturas foi de 25.0 graus Celsius. Os meses acima da média foram:
# Janeiro: 26.0
# Agosto: 27.0
# Setembro: 31.0
# Outubro: 29.0
# Novembro: 30.0
# Dezembro: 34.0

# %% [markdown]
# 11) Uma empresa de e-commerce está interessada em analisar as vendas dos seus produtos. Os dados das vendas foram armazenados em um dicionário:
#
#     {'Produto A': 300, 'Produto B': 80, 'Produto C': 60, 'Produto D': 200, 'Produto E': 250, 'Produto F': 30}
#
#     Escreva um código que calcule o total de vendas e o produto mais vendido.

# %%
vendas = {'Produto A': 300,'Produto B': 80,'Produto C': 400,'Produto D': 200, 'Produto E': 250, 'Produto F': 30}

print(f'Total de vendas: {sum(vendas.values())}')

for chave, valor in vendas.items():
    if valor == max(vendas.values()):
        mais_vendido = chave

print(f'O produto mais vendido foi o {mais_vendido} com {max(vendas.values())} itens vendidos.')
# Out:
# Total de vendas: 1260
# O produto mais vendido foi o Produto C com 400 itens vendidos.

# %% [markdown]
# 12) Uma pesquisa de mercado foi feita para decidir qual design de marca infantil mais agrada as crianças. A pesquisa foi feita e o votos computados podem ser observados abaixo:
#
#     Tabela de votos da marca
#
#     Design 1 - 1334 votos
#
#     Design 2 - 982 votos
#
#     Design 3 - 1751 votos
#
#     Design 4 - 210 votos
#
#     Design 5 - 1811 votos
#
#
# Adapte os dados fornecidos para uma estrutura de dicionário. A partir dele, informe o design vencedor e a porcentagem de votos recebidos.

# %%
votos = {'Design 1' : 1334 , 'Design 2' : 982 , 'Design 3' : 1751 ,'Design 4' : 210 , 'Design 5' : 1811}

for chave, valor in votos.items():
    if valor == max(votos.values()):
        mais_votado = chave

total = sum(votos.values())
percentagem = (votos[mais_votado]*100) / total

print(f'O Design mais votado foi o {mais_votado} com {max(votos.values())} votos, representando {percentagem}% do total de votos.')
# Out:
# O Design mais votado foi o Design 5 com 1811 votos, representando 29.747043363994745% do total de votos.

# %% [markdown]
# 13) As pessoas colaboradoras de um setor da empresa que você trabalha vão receber um abono correspondente a 10% do salário devido ao ótimo desempenho do time. O setor financeiro solicitou sua ajuda para a verificação das consequências financeiras que esse abono irá gerar nos recursos. Assim, foi encaminhada para você uma lista com os salários que receberão o abono: [1172, 1644, 2617, 5130, 5532, 6341, 6650, 7238, 7685, 7782, 7903]. O abono de cada colaborador(a) não pode ser inferior a 200. Em código, transforme cada um dos salários em chaves de um dicionário e o abono de cada salário no elemento. Depois, informe o total de gastos com o abono, quantos(as) colaboradores(as) receberam o abono mínimo e qual o maior valor de abono fornecido.

# %%
salarios = [1172, 1644, 2617, 5130, 5532, 6341, 6650, 7238, 7685, 7782, 7903]
dic = {}
minimo = 0

for i in salarios:
    if i < 2000:
        abono = 200.00
        dic[i] = round(abono,2)
        minimo += 1
    else:
        abono = (i*0.10)
        dic[i] = round(abono,2)

print(f'Total do gastos dos abonos: R$ {sum(dic.values())}')
print(f'{minimo} funcionários receberam o abono mínimo.')
print(f'O maior abono fornecido foi de R$ {max(dic.values())}')
# Out:
# Total do gastos dos abonos: R$ 6087.8
# 2 funcionários receberam o abono mínimo.
# O maior abono fornecido foi de R$ 790.3

# %% [markdown]
# 14) Uma equipe de cientistas de dados está estudando a diversidade biológica em uma floresta. A equipe fez a coleta de informações sobre o número de espécies de plantas e animais em cada área dessa floresta e armazenou essas informações em um dicionário. Nele, a chave descreve a área dos dados e os valores nas listas correspondem às espécies de plantas e animais nas áreas, respectivamente.
#
# Escreva um código para calcular a média de espécies por área e identificar a área com a maior diversidade biológica. Dica: use as funções built-in sum() e len().

# %%
dic =   {'Área Norte': [2819, 7236],
        'Área Leste': [1440, 9492],
        'Área Sul': [5969, 7496],
        'Área Oeste': [14446, 49688],
        'Área Centro': [22558, 45148]}

medias = []

for valor in dic.values():
    media = sum(valor) / len(valor)
    medias.append(media)

maior = medias.index(max(medias))

area_maior = list(dic.keys())[maior]

print(f'A área com maior diversidade biológica é a {area_maior} com média de {max(medias)} espécies.')
# Out:
# A área com maior diversidade biológica é a Área Centro com média de 33853.0 espécies.

# %% [markdown]
# 15) O setor de RH da sua empresa te pediu uma ajuda para analisar as idades de colaboradores(as) de 4 setores da empresa. Para isso, foram fornecidos os seguintes dados:
#
# Sabendo que cada setor tem 10 colaboradores(as), construa um código que calcule a média de idade de cada setor, a idade média geral entre todos os setores e quantas pessoas estão acima da idade média geral.

# %%
entrada =    {'Setor A': [22, 26, 30, 30, 35, 38, 40, 56, 57, 65],
            'Setor B': [22, 24, 26, 33, 41, 49, 50, 54, 60, 64],
            'Setor C': [23, 26, 26, 29, 34, 35, 36, 41, 52, 56],
            'Setor D': [19, 20, 25, 27, 34, 39, 42, 44, 50, 65]}

idades = []

for valor in entrada.values():
    idades.append(valor)

setor_A = idades[0]
setor_B = idades[1]
setor_C = idades[2]
setor_D = idades[3]

print(f'A media de idade do setor A é de: {sum(setor_A)/10} anos. ')
print(f'A media de idade do setor B é de: {sum(setor_B)/10} anos. ')
print(f'A media de idade do setor c é de: {sum(setor_C)/10} anos. ')
print(f'A media de idade do setor D é de: {sum(setor_D)/10} anos. ')

soma_idades = (sum(setor_A) + sum(setor_B) + sum(setor_C) + sum(setor_D))
soma_idades
# Out:
# A media de idade do setor A é de: 39.9 anos.
# A media de idade do setor B é de: 42.3 anos.
# A media de idade do setor c é de: 35.8 anos.
# A media de idade do setor D é de: 36.5 anos.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-438588781.py in <cell line: 0>()
#      19 print(f'A media de idade do setor D é de: {sum(setor_D)/10} anos. ')
#      20
# ---> 21 soma = sum(entrada.values())
#      22 soma
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'
